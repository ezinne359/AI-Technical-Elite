# %%
from __future__ import print_function

# %%
import pandas as pd

#replace file name with relative location in your local folder
name_basics = pd.read_csv("names.tsv", delimiter = "\t", nrows = 200)
title_basics = pd.read_csv("titles.tsv", delimiter = "\t")

#selects people who are listed as an actor/actress
is_actor = name_basics['primaryProfession'].str.contains("actor") | name_basics['primaryProfession'].str.contains("actress")

name_actor = name_basics[is_actor]

#filters out actor/actress with no known titles
has_title = name_actor['knownForTitles'] != '\\N'
name_actor = name_actor[has_title]

has_genre = title_basics['genres'] != '\\N'
title_basics = title_basics[has_genre]

name_actor
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         nconst          primaryName birthYear deathYear  \
# 0    nm0000001         Fred Astaire      1899      1987
# 1    nm0000002        Lauren Bacall      1924      2014
# 2    nm0000003      Brigitte Bardot      1934        \N
# 3    nm0000004         John Belushi      1949      1982
# 4    nm0000005       Ingmar Bergman      1918      2007
# 5    nm0000006       Ingrid Bergman      1915      1982
# 6    nm0000007      Humphrey Bogart      1899      1957
# 7    nm0000008        Marlon Brando      1924      2004
# 8    nm0000009       Richard Burton      1925      1984
# 9    nm0000010         James Cagney      1899      1986
# 10   nm0000011          Gary Cooper      1901      1961
# 11   nm0000012          Bette Davis      1908      1989
# 12   nm0000013            Doris Day      1922      2019
# 13   nm0000014  Olivia de Havilland      1916        \N
# 14   nm0000015           James Dean      1931      1955
# 16   nm0000017     Marlene Dietrich      1901      1992
# 17   nm0000018         Kirk Douglas      1916        \N
# 19   nm0000020          Henry Fonda      1905      1982
# 20   nm0000021        Joan Fontaine      1917      2013
# 21   nm0000022          Clark Gable      1901      1960
# 22   nm0000023         Judy Garland      1922      1969
# 23   nm0000024         John Gielgud      1904      2000
# 25   nm0000026           Cary Grant      1904      1986
# 26   nm0000027        Alec Guinness      1914      2000
# 27   nm0000028        Rita Hayworth      1918      1987
# 28   nm0000029    Margaux Hemingway      1954      1996
# 29   nm0000030       Audrey Hepburn      1929      1993
# 30   nm0000031    Katharine Hepburn      1907      2003
# 31   nm0000032      Charlton Heston      1923      2008
# 32   nm0000033     Alfred Hitchcock      1899      1980
# ..         ...                  ...       ...       ...
# 167  nm0000168    Samuel L. Jackson      1948        \N
# 168  nm0000169      Tommy Lee Jones      1946        \N
# 169  nm0000170       Milla Jovovich      1975        \N
# 170  nm0000171          Ashley Judd      1968        \N
# 171  nm0000172        Harvey Keitel      1939        \N
# 172  nm0000173        Nicole Kidman      1967        \N
# 173  nm0000174           Val Kilmer      1959        \N
# 174  nm0000175         Stephen King      1947        \N
# 175  nm0000176     Nastassja Kinski      1961        \N
# 176  nm0000177          Kevin Kline      1947        \N
# 177  nm0000178           Diane Lane      1965        \N
# 178  nm0000179             Jude Law      1972        \N
# 180  nm0000181     Heather Locklear      1961        \N
# 181  nm0000182       Jennifer Lopez      1969        \N
# 182  nm0000183          Traci Lords      1968        \N
# 184  nm0000185       Dolph Lundgren      1957        \N
# 186  nm0000187              Madonna      1958        \N
# 187  nm0000188         Steve Martin      1945        \N
# 188  nm0000189       Jenny McCarthy      1972        \N
# 189  nm0000190  Matthew McConaughey      1969        \N
# 190  nm0000191        Ewan McGregor      1971        \N
# 191  nm0000192        Alyssa Milano      1972        \N
# 192  nm0000193           Demi Moore      1962        \N
# 193  nm0000194       Julianne Moore      1960        \N
# 194  nm0000195          Bill Murray      1950        \N
# 195  nm0000196           Mike Myers      1963        \N
# 196  nm0000197       Jack Nicholson      1937        \N
# 197  nm0000198          Gary Oldman      1958        \N
# 198  nm0000199            Al Pacino      1940        \N
# 199  nm0000200          Bill Paxton      1955      2017
#
#                          primaryProfession  \
# 0           soundtrack,actor,miscellaneous
# 1                       actress,soundtrack
# 2              actress,soundtrack,producer
# 3                  actor,writer,soundtrack
# 4                    writer,director,actor
# 5              actress,soundtrack,producer
# 6                actor,soundtrack,producer
# 7                actor,soundtrack,director
# 8                actor,producer,soundtrack
# 9                actor,soundtrack,director
# 10               actor,soundtrack,producer
# 11   actress,soundtrack,make_up_department
# 12             soundtrack,actress,producer
# 13                      actress,soundtrack
# 14                     actor,miscellaneous
# 16     soundtrack,actress,music_department
# 17               actor,producer,soundtrack
# 19               actor,producer,soundtrack
# 20             actress,soundtrack,producer
# 21               actor,soundtrack,producer
# 22                      soundtrack,actress
# 23                   actor,writer,director
# 25               actor,soundtrack,producer
# 26                 actor,soundtrack,writer
# 27             actress,soundtrack,producer
# 28                   actress,miscellaneous
# 29                      actress,soundtrack
# 30               actress,soundtrack,writer
# 31                   actor,director,writer
# 32                 actor,director,producer
# ..                                     ...
# 167              actor,producer,soundtrack
# 168              actor,director,soundtrack
# 169            actress,soundtrack,producer
# 170              actress,producer,director
# 171              actor,producer,soundtrack
# 172            actress,producer,soundtrack
# 173              actor,soundtrack,producer
# 174                  writer,producer,actor
# 175            actress,producer,soundtrack
# 176              actor,soundtrack,director
# 177                     actress,soundtrack
# 178              actor,producer,soundtrack
# 180            actress,producer,soundtrack
# 181            actress,producer,soundtrack
# 182            actress,soundtrack,producer
# 184                actor,producer,director
# 186    soundtrack,actress,music_department
# 187                writer,actor,soundtrack
# 188                actress,producer,writer
# 189              actor,producer,soundtrack
# 190                actor,writer,soundtrack
# 191            actress,producer,soundtrack
# 192              actress,producer,director
# 193            actress,soundtrack,producer
# 194                actor,soundtrack,writer
# 195                actor,writer,soundtrack
# 196              actor,soundtrack,producer
# 197              actor,soundtrack,producer
# 198              actor,soundtrack,director
# 199                  actor,producer,writer
#
#                               knownForTitles
# 0    tt0053137,tt0072308,tt0043044,tt0050419
# 1    tt0037382,tt0038355,tt0071877,tt0117057
# 2    tt0059956,tt0054452,tt0057345,tt0049189
# 3    tt0078723,tt0080455,tt0072562,tt0077975
# 4    tt0083922,tt0069467,tt0050986,tt0050976
# 5    tt0036855,tt0077711,tt0038787,tt0038109
# 6    tt0034583,tt0033870,tt0037382,tt0043265
# 7    tt0044081,tt0070849,tt0078788,tt0068646
# 8    tt0087803,tt0057877,tt0059749,tt0061184
# 9    tt0031867,tt0035575,tt0055256,tt0029870
# 10   tt0034167,tt0035896,tt0027996,tt0044706
# 11   tt0035140,tt0042192,tt0056687,tt0031210
# 12   tt0055100,tt0053172,tt0048317,tt0060463
# 13   tt0041452,tt0029843,tt0031381,tt0040806
# 14   tt0048545,tt0049261,tt0039123,tt0048028
# 16   tt0021156,tt0051201,tt0052311,tt0055031
# 17   tt0054331,tt0052365,tt0049456,tt0080736
# 19   tt0032551,tt0050083,tt0064116,tt0082846
# 20   tt0039504,tt0034248,tt0036969,tt0032976
# 21   tt0031381,tt0052278,tt0025316,tt0026752
# 22   tt0055031,tt0047522,tt0032138,tt0037059
# 23   tt0045943,tt0082031,tt0071877,tt0117631
# 25   tt0053125,tt0032599,tt0048728,tt0056923
# 26   tt0041546,tt0051739,tt0076759,tt0050212
# 27   tt0038559,tt0040525,tt0040552,tt0036723
# 28   tt0110138,tt0077800,tt0074802,tt0102122
# 29   tt0054698,tt0056923,tt0046250,tt0058385
# 30   tt0082846,tt0032904,tt0043265,tt0063227
# 31   tt0070723,tt0049833,tt0063442,tt0052618
# 32   tt0052357,tt0056869,tt0054215,tt0053125
# ..                                       ...
# 167  tt0110912,tt3460252,tt0119396,tt0417148
# 168  tt0106977,tt2398231,tt0443272,tt0477348
# 169  tt0432021,tt0119116,tt1220198,tt1220634
# 170  tt0470705,tt0352277,tt0150377,tt0113277
# 171  tt2278388,tt0105236,tt0110912,tt0103759
# 172  tt0159365,tt0203009,tt0230600,tt0274558
# 173  tt0101761,tt0373469,tt0235737,tt0120053
# 174  tt0111161,tt0120689,tt0091499,tt0083767
# 175  tt0087884,tt0083722,tt0080009,tt0111400
# 176  tt0095159,tt0106673,tt0119360,tt0120891
# 177  tt2096673,tt0086066,tt0250797,tt0328589
# 178  tt0346156,tt0376541,tt2278388,tt0134119
# 180  tt0119695,tt0103491,tt0380623,tt0087262
# 181  tt0209958,tt0252076,tt0299930,tt3181822
# 182  tt1984153,tt0120611,tt0099329,tt1007028
# 184  tt0089927,tt0113481,tt0105698,tt1764651
# 186  tt0246460,tt0099422,tt0116250,tt0156841
# 187  tt0102250,tt0383216,tt0093886,tt0079367
# 188  tt0134084,tt0131857,tt0327643,tt0455967
# 189  tt1935179,tt0790636,tt1915581,tt1726669
# 190  tt1322269,tt0117951,tt0120915,tt0203009
# 191  tt0116287,tt0086827,tt0088944,tt0158552
# 192  tt0119173,tt0107211,tt0305357,tt0117765
# 193  tt0842926,tt0297884,tt3316960,tt2172584
# 194  tt0362270,tt0128445,tt0335266,tt1748122
# 195  tt0811138,tt0145660,tt0295178,tt0118655
# 196  tt0119822,tt0073486,tt0071315,tt0407887
# 197  tt0103874,tt0468569,tt1340800,tt4555426
# 198  tt0099422,tt0070666,tt0068646,tt0072890
# 199  tt0117998,tt0264616,tt0090605,tt0112384
#
# [175 rows x 6 columns]

# %%
genre_list = []

#creates a new column genres in name_actor by referencing known titles and retrieving genre data.
for index, row in name_actor.iterrows():
    title_str = row['knownForTitles']
    title_list = title_str.split(",")
    genre_str = ''
    for i in title_list:
        title_index = title_basics.index[title_basics['tconst'] == i].tolist()
        if len(title_index) == 0:
            continue
        title_row = title_basics.at[title_index[0], 'genres']
        genre_str += title_row + ','
    genre_str = genre_str[:-1]
    genre_list.append(genre_str)


name_actor.insert(6,"genre", genre_list)
name_actor
#export name_actor as csv
# name_actor.to_csv('actor_genre.csv')
# Out:
#         nconst          primaryName birthYear deathYear  \
# 0    nm0000001         Fred Astaire      1899      1987
# 1    nm0000002        Lauren Bacall      1924      2014
# 2    nm0000003      Brigitte Bardot      1934        \N
# 3    nm0000004         John Belushi      1949      1982
# 4    nm0000005       Ingmar Bergman      1918      2007
# 5    nm0000006       Ingrid Bergman      1915      1982
# 6    nm0000007      Humphrey Bogart      1899      1957
# 7    nm0000008        Marlon Brando      1924      2004
# 8    nm0000009       Richard Burton      1925      1984
# 9    nm0000010         James Cagney      1899      1986
# 10   nm0000011          Gary Cooper      1901      1961
# 11   nm0000012          Bette Davis      1908      1989
# 12   nm0000013            Doris Day      1922      2019
# 13   nm0000014  Olivia de Havilland      1916        \N
# 14   nm0000015           James Dean      1931      1955
# 16   nm0000017     Marlene Dietrich      1901      1992
# 17   nm0000018         Kirk Douglas      1916        \N
# 19   nm0000020          Henry Fonda      1905      1982
# 20   nm0000021        Joan Fontaine      1917      2013
# 21   nm0000022          Clark Gable      1901      1960
# 22   nm0000023         Judy Garland      1922      1969
# 23   nm0000024         John Gielgud      1904      2000
# 25   nm0000026           Cary Grant      1904      1986
# 26   nm0000027        Alec Guinness      1914      2000
# 27   nm0000028        Rita Hayworth      1918      1987
# 28   nm0000029    Margaux Hemingway      1954      1996
# 29   nm0000030       Audrey Hepburn      1929      1993
# 30   nm0000031    Katharine Hepburn      1907      2003
# 31   nm0000032      Charlton Heston      1923      2008
# 32   nm0000033     Alfred Hitchcock      1899      1980
# ..         ...                  ...       ...       ...
# 167  nm0000168    Samuel L. Jackson      1948        \N
# 168  nm0000169      Tommy Lee Jones      1946        \N
# 169  nm0000170       Milla Jovovich      1975        \N
# 170  nm0000171          Ashley Judd      1968        \N
# 171  nm0000172        Harvey Keitel      1939        \N
# 172  nm0000173        Nicole Kidman      1967        \N
# 173  nm0000174           Val Kilmer      1959        \N
# 174  nm0000175         Stephen King      1947        \N
# 175  nm0000176     Nastassja Kinski      1961        \N
# 176  nm0000177          Kevin Kline      1947        \N
# 177  nm0000178           Diane Lane      1965        \N
# 178  nm0000179             Jude Law      1972        \N
# 180  nm0000181     Heather Locklear      1961        \N
# 181  nm0000182       Jennifer Lopez      1969        \N
# 182  nm0000183          Traci Lords      1968        \N
# 184  nm0000185       Dolph Lundgren      1957        \N
# 186  nm0000187              Madonna      1958        \N
# 187  nm0000188         Steve Martin      1945        \N
# 188  nm0000189       Jenny McCarthy      1972        \N
# 189  nm0000190  Matthew McConaughey      1969        \N
# 190  nm0000191        Ewan McGregor      1971        \N
# 191  nm0000192        Alyssa Milano      1972        \N
# 192  nm0000193           Demi Moore      1962        \N
# 193  nm0000194       Julianne Moore      1960        \N
# 194  nm0000195          Bill Murray      1950        \N
# 195  nm0000196           Mike Myers      1963        \N
# 196  nm0000197       Jack Nicholson      1937        \N
# 197  nm0000198          Gary Oldman      1958        \N
# 198  nm0000199            Al Pacino      1940        \N
# 199  nm0000200          Bill Paxton      1955      2017
#
#                          primaryProfession  \
# 0           soundtrack,actor,miscellaneous
# 1                       actress,soundtrack
# 2              actress,soundtrack,producer
# 3                  actor,writer,soundtrack
# 4                    writer,director,actor
# 5              actress,soundtrack,producer
# 6                actor,soundtrack,producer
# 7                actor,soundtrack,director
# 8                actor,producer,soundtrack
# 9                actor,soundtrack,director
# 10               actor,soundtrack,producer
# 11   actress,soundtrack,make_up_department
# 12             soundtrack,actress,producer
# 13                      actress,soundtrack
# 14                     actor,miscellaneous
# 16     soundtrack,actress,music_department
# 17               actor,producer,soundtrack
# 19               actor,producer,soundtrack
# 20             actress,soundtrack,producer
# 21               actor,soundtrack,producer
# 22                      soundtrack,actress
# 23                   actor,writer,director
# 25               actor,soundtrack,producer
# 26                 actor,soundtrack,writer
# 27             actress,soundtrack,producer
# 28                   actress,miscellaneous
# 29                      actress,soundtrack
# 30               actress,soundtrack,writer
# 31                   actor,director,writer
# 32                 actor,director,producer
# ..                                     ...
# 167              actor,producer,soundtrack
# 168              actor,director,soundtrack
# 169            actress,soundtrack,producer
# 170              actress,producer,director
# 171              actor,producer,soundtrack
# 172            actress,producer,soundtrack
# 173              actor,soundtrack,producer
# 174                  writer,producer,actor
# 175            actress,producer,soundtrack
# 176              actor,soundtrack,director
# 177                     actress,soundtrack
# 178              actor,producer,soundtrack
# 180            actress,producer,soundtrack
# 181            actress,producer,soundtrack
# 182            actress,soundtrack,producer
# 184                actor,producer,director
# 186    soundtrack,actress,music_department
# 187                writer,actor,soundtrack
# 188                actress,producer,writer
# 189              actor,producer,soundtrack
# 190                actor,writer,soundtrack
# 191            actress,producer,soundtrack
# 192              actress,producer,director
# 193            actress,soundtrack,producer
# 194                actor,soundtrack,writer
# 195                actor,writer,soundtrack
# 196              actor,soundtrack,producer
# 197              actor,soundtrack,producer
# 198              actor,soundtrack,director
# 199                  actor,producer,writer
#
#                               knownForTitles  \
# 0    tt0053137,tt0072308,tt0043044,tt0050419
# 1    tt0037382,tt0038355,tt0071877,tt0117057
# 2    tt0059956,tt0054452,tt0057345,tt0049189
# 3    tt0078723,tt0080455,tt0072562,tt0077975
# 4    tt0083922,tt0069467,tt0050986,tt0050976
# 5    tt0036855,tt0077711,tt0038787,tt0038109
# 6    tt0034583,tt0033870,tt0037382,tt0043265
# 7    tt0044081,tt0070849,tt0078788,tt0068646
# 8    tt0087803,tt0057877,tt0059749,tt0061184
# 9    tt0031867,tt0035575,tt0055256,tt0029870
# 10   tt0034167,tt0035896,tt0027996,tt0044706
# 11   tt0035140,tt0042192,tt0056687,tt0031210
# 12   tt0055100,tt0053172,tt0048317,tt0060463
# 13   tt0041452,tt0029843,tt0031381,tt0040806
# 14   tt0048545,tt0049261,tt0039123,tt0048028
# 16   tt0021156,tt0051201,tt0052311,tt0055031
# 17   tt0054331,tt0052365,tt0049456,tt0080736
# 19   tt0032551,tt0050083,tt0064116,tt0082846
# 20   tt0039504,tt0034248,tt0036969,tt0032976
# 21   tt0031381,tt0052278,tt0025316,tt0026752
# 22   tt0055031,tt0047522,tt0032138,tt0037059
# 23   tt0045943,tt0082031,tt0071877,tt0117631
# 25   tt0053125,tt0032599,tt0048728,tt0056923
# 26   tt0041546,tt0051739,tt0076759,tt0050212
# 27   tt0038559,tt0040525,tt0040552,tt0036723
# 28   tt0110138,tt0077800,tt0074802,tt0102122
# 29   tt0054698,tt0056923,tt0046250,tt0058385
# 30   tt0082846,tt0032904,tt0043265,tt0063227
# 31   tt0070723,tt0049833,tt0063442,tt0052618
# 32   tt0052357,tt0056869,tt0054215,tt0053125
# ..                                       ...
# 167  tt0110912,tt3460252,tt0119396,tt0417148
# 168  tt0106977,tt2398231,tt0443272,tt0477348
# 169  tt0432021,tt0119116,tt1220198,tt1220634
# 170  tt0470705,tt0352277,tt0150377,tt0113277
# 171  tt2278388,tt0105236,tt0110912,tt0103759
# 172  tt0159365,tt0203009,tt0230600,tt0274558
# 173  tt0101761,tt0373469,tt0235737,tt0120053
# 174  tt0111161,tt0120689,tt0091499,tt0083767
# 175  tt0087884,tt0083722,tt0080009,tt0111400
# 176  tt0095159,tt0106673,tt0119360,tt0120891
# 177  tt2096673,tt0086066,tt0250797,tt0328589
# 178  tt0346156,tt0376541,tt2278388,tt0134119
# 180  tt0119695,tt0103491,tt0380623,tt0087262
# 181  tt0209958,tt0252076,tt0299930,tt3181822
# 182  tt1984153,tt0120611,tt0099329,tt1007028
# 184  tt0089927,tt0113481,tt0105698,tt1764651
# 186  tt0246460,tt0099422,tt0116250,tt0156841
# 187  tt0102250,tt0383216,tt0093886,tt0079367
# 188  tt0134084,tt0131857,tt0327643,tt0455967
# 189  tt1935179,tt0790636,tt1915581,tt1726669
# 190  tt1322269,tt0117951,tt0120915,tt0203009
# 191  tt0116287,tt0086827,tt0088944,tt0158552
# 192  tt0119173,tt0107211,tt0305357,tt0117765
# 193  tt0842926,tt0297884,tt3316960,tt2172584
# 194  tt0362270,tt0128445,tt0335266,tt1748122
# 195  tt0811138,tt0145660,tt0295178,tt0118655
# 196  tt0119822,tt0073486,tt0071315,tt0407887
# 197  tt0103874,tt0468569,tt1340800,tt4555426
# 198  tt0099422,tt0070666,tt0068646,tt0072890
# 199  tt0117998,tt0264616,tt0090605,tt0112384
#
#                                                  genre
# 0    Drama,Romance,Sci-Fi,Action,Drama,Thriller,Bio...
# 1    Adventure,Comedy,Film-Noir,Crime,Film-Noir,Mys...
# 2    Adventure,Comedy,Romance,Drama,Drama,Romance,D...
# 3    Action,Comedy,War,Adventure,Comedy,Crime,Comed...
# 4              Drama,Drama,Drama,Romance,Drama,Fantasy
# 5    Crime,Drama,Film-Noir,Drama,Music,Drama,Film-N...
# 6    Drama,Romance,War,Film-Noir,Mystery,Adventure,...
# 7    Drama,Drama,Romance,Drama,Mystery,War,Crime,Drama
# 8    Drama,Sci-Fi,Biography,Drama,History,Drama,Thr...
# 9    Action,Crime,Drama,Biography,Drama,Musical,Com...
# 10   Biography,Drama,History,Adventure,Drama,Histor...
# 11   Drama,Romance,Drama,Drama,Horror,Thriller,Dram...
# 12   Comedy,Drama,Romance,Comedy,Romance,Biography,...
# 13   Drama,Romance,Action,Adventure,Romance,Drama,H...
# 14                     Drama,Drama,Western,Drama,Drama
# 16   Drama,Romance,Crime,Drama,Mystery,Crime,Drama,...
# 17   Adventure,Biography,Drama,Action,Adventure,His...
# 19                   Drama,History,Drama,Western,Drama
# 20   Crime,Drama,Film-Noir,Mystery,Thriller,Drama,R...
# 21   Drama,History,Romance,Comedy,Romance,Comedy,Ro...
# 22   Drama,War,Drama,Musical,Romance,Adventure,Fami...
# 23   Biography,Drama,History,Comedy,Romance,Crime,D...
# 25   Adventure,Mystery,Thriller,Comedy,Drama,Romanc...
# 26   Comedy,Crime,Comedy,Action,Adventure,Fantasy,A...
# 27   Drama,Film-Noir,Romance,Crime,Drama,Film-Noir,...
# 28   Drama,Horror,Romance,Horror,Sci-Fi,Thriller,Cr...
# 29   Comedy,Drama,Romance,Comedy,Mystery,Romance,Co...
# 30   Drama,Comedy,Romance,Adventure,Drama,Romance,B...
# 31   Crime,Mystery,Sci-Fi,Adventure,Drama,Adventure...
# 32   Mystery,Romance,Thriller,Drama,Horror,Mystery,...
# ..                                                 ...
# 167  Crime,Drama,Crime,Drama,Thriller,Action,Crime,...
# 168  Action,Crime,Drama,Drama,Western,Biography,Dra...
# 169  Action,Horror,Sci-Fi,Action,Adventure,Sci-Fi,M...
# 170  Drama,Thriller,Biography,Drama,Music,Crime,Dra...
# 171  Adventure,Comedy,Crime,Crime,Drama,Thriller,Cr...
# 172  Adventure,Drama,History,Drama,Musical,Romance,...
# 173  Biography,Drama,Music,Action,Comedy,Crime,Crim...
# 174  Drama,Crime,Drama,Fantasy,Action,Comedy,Horror...
# 175  Drama,Fantasy,Horror,Thriller,Drama,Romance,Ac...
# 176  Comedy,Crime,Comedy,Romance,Comedy,Romance,Act...
# 177  Adventure,Animation,Comedy,Crime,Drama,Drama,R...
# 178  Action,Adventure,Crime,Drama,Romance,Adventure...
# 180  Action,Comedy,Crime,Drama,Romance,Comedy,Famil...
# 181  Horror,Sci-Fi,Thriller,Comedy,Drama,Romance,Co...
# 182  Comedy,Drama,Horror,Action,Horror,Sci-Fi,Comed...
# 184  Drama,Sport,Action,Drama,Sci-Fi,Action,Sci-Fi,...
# 186  Action,Adventure,Thriller,Action,Comedy,Crime,...
# 187  Comedy,Drama,Fantasy,Adventure,Comedy,Crime,Co...
# 188  Horror,Mystery,Comedy,Sport,Comedy,Romance,Com...
# 189  Drama,Biography,Drama,Comedy,Drama,Crime,Drama...
# 190  Comedy,Drama,Drama,Action,Adventure,Fantasy,Dr...
# 191  Drama,Thriller,Comedy,Family,Romance,Action,Ad...
# 192  Action,Drama,War,Drama,Romance,Action,Adventur...
# 193            Comedy,Drama,Romance,Drama,Comedy,Drama
# 194  Action,Adventure,Comedy,Comedy,Drama,Drama,Com...
# 195  Comedy,Romance,Sport,Action,Adventure,Comedy,A...
# 196  Comedy,Drama,Romance,Drama,Drama,Mystery,Thril...
# 197   Horror,Action,Crime,Drama,Drama,Mystery,Thriller
# 198  Action,Comedy,Crime,Biography,Crime,Drama,Crim...
# 199  Action,Adventure,Thriller,Crime,Drama,Thriller...
#
# [175 rows x 7 columns]

# %%
import binascii

# %%
#get table with only specific columns
name_genre = name_actor[['nconst', 'primaryName', 'genre']]

top_genres = []
for index, row in name_genre.iterrows():
    genres = name_genre.at[index, 'genre'].split(',')
    d = {}
    for genre in genres:
        if genre not in d:
            d[genre] = 0
        d[genre] += 1
    sorted_d = sorted(d.items(), key = lambda t: t[1], reverse=True)
    top = []
    for i in range(3):
        if len(sorted_d) >= i + 1:
            top.append(sorted_d[i][0])
    top_genres.append(top)
name_genre.insert(3, 'top genres', top_genres)

#make name_genre only have the top 3 genres for each actor
name_genre = name_genre.drop(columns=['genre'])

#make dictionary mapping genres to ints
#d = {}
#i = 0
#for genre in top_genre:
#    if genre not in d:
#        d[genre] = i
#        i+= 1

#convert str names to unique int representations
names = name_genre['primaryName']
names_nums = []
for name in names:
    name_hex = binascii.hexlify(name.encode('utf-8'))
    names_nums.append(int(name_hex, 16))
        
#get top genre for each actor
top_genre = []
for index, row in name_genre.iterrows():
    top_genre.append(name_genre.at[index, 'top genres'][0])

#get list of genres by their int representations
genre_nums = []
for genre in top_genre:
    genre_nums.append(d[genre])

name_genre_identifiers = name_genre.drop(columns=['nconst', 'top genres'])
name_genre_identifiers['top genre'] = top_genre
name_genre_identifiers['name identifier'] = names_nums #model input
name_genre_identifiers['top genre identifier'] = genre_nums #model output
name_genre_identifiers
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-13-2ba4e1fb82b1> in <module>
#      44 genre_nums = []
#      45 for genre in top_genre:
# ---> 46     genre_nums.append(d[genre])
#      47
#      48 name_genre_identifiers = name_genre.drop(columns=['nconst', 'top genres'])
#
# KeyError: 'Comedy'

# %%
names = name_genre_identifiers['primaryName']
top_genre = name_genre_identifiers['top genre']
X_train, X_test, y_train, y_test = train_test_split(names, top_genre, test_size=0.2, random_state=0)

#model = LogisticRegression(solver='lbfgs', multi_class='multinomial')

#train the algorithm
#model.fit(X_train, y_train)
#y_pred = model.predict(X_test)
#y_pred #predicted genre
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-1f445e0acbe8> in <module>
# ----> 1 names = name_genre_identifiers['primaryName']
#       2 top_genre = name_genre_identifiers['top genre']
#       3 X_train, X_test, y_train, y_test = train_test_split(names, top_genre, test_size=0.2, random_state=0)
#       4
#       5 #model = LogisticRegression(solver='lbfgs', multi_class='multinomial')
#
# NameError: name 'name_genre_identifiers' is not defined

# %%
### above this cell is just setting data up for the model ###
### here is where we create and test the model ###
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn import metrics
# %matplotlib inline

# %%
# export relevant_data as csv
name_genre_identifiers = pd.read_csv('name_genre_identifiers.csv')

# %%
# !pip install finetune
# Out:
# Requirement already satisfied: finetune in /opt/conda/lib/python3.7/site-packages (0.8.3)
# Requirement already satisfied: joblib>=0.12.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.13.2)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (1.3.0)
# Requirement already satisfied: bs4>=0.0.1 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.0.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.21.3)
# Requirement already satisfied: imblearn>=0.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.0)
# Requirement already satisfied: nltk>=3.2.4 in /opt/conda/lib/python3.7/site-packages (from finetune) (3.4.5)
# Requirement already satisfied: regex>=2019.03.12 in /opt/conda/lib/python3.7/site-packages (from finetune) (2019.8.19)
# Requirement already satisfied: lxml>=4.3.3 in /opt/conda/lib/python3.7/site-packages (from finetune) (4.4.1)
# Requirement already satisfied: h5py>=2.8.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (2.9.0)
# Requirement already satisfied: pandas>=0.23.1 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.23.4)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (4.32.2)
# Requirement already satisfied: ftfy>=4.4.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (5.6)
# Requirement already satisfied: spacy>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (2.2.1)
# Requirement already satisfied: numpy>=1.13.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (1.17.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from bs4>=0.0.1->finetune) (4.8.0)
# Requirement already satisfied: imbalanced-learn in /opt/conda/lib/python3.7/site-packages (from imblearn>=0.0->finetune) (0.5.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from nltk>=3.2.4->finetune) (1.12.0)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.1->finetune) (2019.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.1->finetune) (2.8.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from ftfy>=4.4.0->finetune) (0.1.7)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (7.1.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (3.0.2)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (2.22.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (1.0.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.9.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.2.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (2.0.2)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->bs4>=0.0.1->finetune) (1.9.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (3.0.4)

# %%
#pip install absl-py
# Out:
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from absl-py) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast==0.2.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (0.33.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.24.1)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (0.8.1)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow) (0.1.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow) (41.0.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow) (2.9.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install tensorflow==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/92/2b/e3af15221da9ff323521565fa3324b0d7c7c5b1d7a8ca66984c8d59cb0ce/tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 77kB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (3.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.0.8)
# Collecting tensorboard<1.16.0,>=1.15.0 (from tensorflow==1.15)
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 10.1MB/s
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (0.8.0)
# Collecting tensorflow-estimator==1.15.1 (from tensorflow==1.15)
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 26.0MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (3.9.1)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.24.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.17.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (0.1.7)
# Requirement already satisfied: gast==0.2.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (1.11.2)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15) (0.33.4)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.9.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (0.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.1)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.0.0
#     Uninstalling tensorboard-2.0.0:
#       Successfully uninstalled tensorboard-2.0.0
#   Found existing installation: tensorflow-estimator 2.0.1
#     Uninstalling tensorflow-estimator-2.0.1:
#       Successfully uninstalled tensorflow-estimator-2.0.1
#   Found existing installation: tensorflow 2.0.0
#     Uninstalling tensorflow-2.0.0:
#       Successfully uninstalled tensorflow-2.0.0
# Successfully installed tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
#import tensorflow as tf

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /opt/conda/lib/python3.7/site-packages
# Requires: numpy, tensorflow-estimator, termcolor, wheel, google-pasta, wrapt, gast, astor, grpcio, keras-preprocessing, protobuf, absl-py, keras-applications, six, opt-einsum, tensorboard
# Required-by:

# %%
print(tf.__version__)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-65f07e81e169> in <module>
# ----> 1 print(tf.__version__)
#
# NameError: name 'tf' is not defined

# %%
! git clone https://github.com/IndicoDataSolutions/finetune
! cd finetune
! python3 setup.py develop
! python3 -m spacy download en
# Out:
# Cloning into 'finetune'...
# remote: Enumerating objects: 404, done.
# remote: Counting objects: 100% (404/404), done.
# remote: Compressing objects: 100% (208/208), done.
# remote: Total 8530 (delta 278), reused 276 (delta 193), pack-reused 8126
# Receiving objects: 100% (8530/8530), 418.60 MiB | 35.05 MiB/s, done.
# Resolving deltas: 100% (6407/6407), done.
# python3: can't open file 'setup.py': [Errno 2] No such file or directory
# Collecting en_core_web_sm==2.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz#egg=en_core_web_sm==2.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz (12.0MB)
#      |████████████████████████████████| 12.0MB 7.2MB/s
# Requirement already satisfied: spacy>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from en_core_web_sm==2.2.0) (2.2.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (3.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.17.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (2.22.0)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (7.1.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.4.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.9.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (2.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (1.25.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (2.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/conda/lib/python3.7/site-packages (from thinc<7.2.0,>=7.1.1->spacy>=2.2.0->en_core_web_sm==2.2.0) (4.32.2)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.0-cp37-none-any.whl size=12019126 sha256=045d21d6cbc4c29391d76dea5b44e4dc844c7b9ab64a5244e1e8cfd2dde8529c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4c4cqkvt/wheels/48/5c/1c/15f9d02afc8221a668d2172446dd8467b20cdb9aef80a172a4
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-2.2.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /opt/conda/lib/python3.7/site-packages/en_core_web_sm -->
# /opt/conda/lib/python3.7/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
#!pip install finetune
# Out:
# Requirement already satisfied: finetune in /opt/conda/lib/python3.7/site-packages (0.8.3)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (1.3.0)
# Requirement already satisfied: bs4>=0.0.1 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.0.1)
# Requirement already satisfied: ftfy>=4.4.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (5.6)
# Requirement already satisfied: regex>=2019.03.12 in /opt/conda/lib/python3.7/site-packages (from finetune) (2019.8.19)
# Requirement already satisfied: scikit-learn>=0.18.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.21.3)
# Requirement already satisfied: h5py>=2.8.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (2.9.0)
# Requirement already satisfied: lxml>=4.3.3 in /opt/conda/lib/python3.7/site-packages (from finetune) (4.4.1)
# Requirement already satisfied: spacy>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (2.2.1)
# Requirement already satisfied: joblib>=0.12.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.13.2)
# Requirement already satisfied: pandas>=0.23.1 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.23.4)
# Requirement already satisfied: imblearn>=0.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (0.0)
# Requirement already satisfied: numpy>=1.13.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (1.17.0)
# Requirement already satisfied: nltk>=3.2.4 in /opt/conda/lib/python3.7/site-packages (from finetune) (3.4.5)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from finetune) (4.32.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from bs4>=0.0.1->finetune) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from ftfy>=4.4.0->finetune) (0.1.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py>=2.8.0->finetune) (1.12.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.4.1)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (7.1.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.9.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (2.22.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (2.0.2)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (0.2.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.7/site-packages (from spacy>=2.0.0->finetune) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.1->finetune) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.1->finetune) (2019.2)
# Requirement already satisfied: imbalanced-learn in /opt/conda/lib/python3.7/site-packages (from imblearn>=0.0->finetune) (0.5.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->bs4>=0.0.1->finetune) (1.9.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.0->finetune) (1.25.3)

# %%
from finetune.base_models import BERT, BERTLarge, GPT2, GPT2Medium, GPT2Large, TextCNN, TCN, RoBERTa, DistilBERT
from finetune import Classifier
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
model = Classifier(base_model = TextCNN)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
X_test
y_pred
# Out:
# INFO:finetune:Saving tensorboard output to /tmp/Finetune3wtvc27x
# NameErrorTraceback (most recent call last)
# <ipython-input-16-4da351e3e2f7> in <module>
#       1 model = Classifier(base_model = TextCNN)
# ----> 2 model.fit(X_train, y_train)
#       3 y_pred = model.predict(X_test)
#       4 X_test
#       5 y_pred
#
# NameError: name 'X_train' is not defined

# %%
 print(y_test)
